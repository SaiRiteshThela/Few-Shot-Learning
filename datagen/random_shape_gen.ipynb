# %%
import numpy as np
from scipy.special import binom
import matplotlib.pyplot as plt
from PIL import Image, ImageDraw, ImagePath


bernstein = lambda n, k, t: binom(n,k)* t**k * (1.-t)**(n-k)

def bezier(points, num=200):
    N = len(points)
    t = np.linspace(0, 1, num=num)
    curve = np.zeros((num, 2))
    for i in range(N):
        curve += np.outer(bernstein(N - 1, i, t), points[i])
    return curve

class Segment():
    def __init__(self, p1, p2, angle1, angle2, **kw):
        self.p1 = p1; self.p2 = p2
        self.angle1 = angle1; self.angle2 = angle2
        self.numpoints = kw.get("numpoints", 100)
        r = kw.get("r", 0.3)
        d = np.sqrt(np.sum((self.p2-self.p1)**2))
        self.r = r*d
        self.p = np.zeros((4,2))
        self.p[0,:] = self.p1[:]
        self.p[3,:] = self.p2[:]
        self.calc_intermediate_points(self.r)

    def calc_intermediate_points(self,r):
        self.p[1,:] = self.p1 + np.array([self.r*np.cos(self.angle1),
                                    self.r*np.sin(self.angle1)])
        self.p[2,:] = self.p2 + np.array([self.r*np.cos(self.angle2+np.pi),
                                    self.r*np.sin(self.angle2+np.pi)])
        self.curve = bezier(self.p,self.numpoints)


def get_curve(points, **kw):
    segments = []
    for i in range(len(points)-1):
        seg = Segment(points[i,:2], points[i+1,:2], points[i,2],points[i+1,2],**kw)
        segments.append(seg)
    curve = np.concatenate([s.curve for s in segments])
    return segments, curve

def ccw_sort(p):
    d = p-np.mean(p,axis=0)
    s = np.arctan2(d[:,0], d[:,1])
    return p[np.argsort(s),:]

def get_bezier_curve(a, rad=0.2, edgy=0):
    """ given an array of points *a*, create a curve through
    those points. 
    *rad* is a number between 0 and 1 to steer the distance of
          control points.
    *edgy* is a parameter which controls how "edgy" the curve is,
           edgy=0 is smoothest."""
    p = np.arctan(edgy)/np.pi+.5
    a = ccw_sort(a)
    a = np.append(a, np.atleast_2d(a[0,:]), axis=0)
    d = np.diff(a, axis=0)
    ang = np.arctan2(d[:,1],d[:,0])
    f = lambda ang : (ang>=0)*ang + (ang<0)*(ang+2*np.pi)
    ang = f(ang)
    ang1 = ang
    ang2 = np.roll(ang,1)
    ang = p*ang1 + (1-p)*ang2 + (np.abs(ang2-ang1) > np.pi )*np.pi
    ang = np.append(ang, [ang[0]])
    a = np.append(a, np.atleast_2d(ang).T, axis=1)
    s, c = get_curve(a, r=rad, method="var")
    x,y = c.T
    return x,y, a


def get_random_points(n=5, scale=0.8, mindst=None, rec=0):
    """ create n random points in the unit square, which are *mindst*
    apart, then scale them."""
    mindst = mindst or .7/n
    a = np.random.rand(n,2)
    d = np.sqrt(np.sum(np.diff(ccw_sort(a), axis=0), axis=1)**2)
    if np.all(d >= mindst) or rec>=200:
        return a*scale
    else:
        return get_random_points(n=n, scale=scale, mindst=mindst, rec=rec+1)

# %%
import numpy as np
from scipy.special import binom
import matplotlib.pyplot as plt
from PIL import Image, ImageDraw, ImagePath

# ... (Include all the previously explained functions here) ...

def generate_filled_bezier_image(size=16, num_points=5, scale=0.8, rad=0.2, edgy=0):
    # Generate random points
    points = get_random_points(n=num_points, scale=scale)

    # Get the x and y coordinates of the Bezier curve
    x, y, _ = get_bezier_curve(points, rad=rad, edgy=edgy)

    # Create a blank image
    img = Image.new("RGB", (size, size), (0, 0, 0))
    draw = ImageDraw.Draw(img)

    # Scale and shift the curve coordinates
    x = (x * (size - 1)).astype(int)
    y = (y * (size - 1)).astype(int)

    # Create a polygon from the curve points
    path = ImagePath.Path(list(zip(x, y)))

    # Fill the polygon
    draw.polygon(list(path), fill=(255, 255, 255))

    return img

# %%
import os
import random
from PIL import ImageChops

def xor_images(img1, img2):
    img1_bw = img1.convert("1")
    img2_bw = img2.convert("1")
    return ImageChops.logical_xor(img1_bw, img2_bw)

def generate_images(num_images=1000, img_size=64):
    output_dir = 'generated_images'
    os.makedirs(output_dir, exist_ok=True)

    for i in range(num_images):
        # Generate one or two images
        img1 = generate_filled_bezier_image(size=img_size)
        if random.random() < 0.5:
            img2 = generate_filled_bezier_image(size=img_size)
            final_img = xor_images(img1, img2)
        else:
            final_img = img1

        # Save the generated image
        final_img.save(os.path.join(output_dir, f'image_{i:05d}.png'))

generate_images(num_images=1000, img_size=64)

# %%
# !zip -r generated_images.zip generated_images
# Out:
#   adding: generated_images/ (stored 0%)
#   adding: generated_images/image_00961.png (stored 0%)
#   adding: generated_images/image_00617.png (stored 0%)
#   adding: generated_images/image_00755.png (stored 0%)
#   adding: generated_images/image_00642.png (stored 0%)
#   adding: generated_images/image_00452.png (stored 0%)
#   adding: generated_images/image_00135.png (stored 0%)
#   adding: generated_images/image_00474.png (stored 0%)
#   adding: generated_images/image_00616.png (stored 0%)
#   adding: generated_images/image_00931.png (stored 0%)
#   adding: generated_images/image_00533.png (deflated 0%)
#   adding: generated_images/image_00292.png (stored 0%)
#   adding: generated_images/image_00408.png (stored 0%)
#   adding: generated_images/image_00278.png (deflated 1%)
#   adding: generated_images/image_00250.png (stored 0%)
#   adding: generated_images/image_00528.png (stored 0%)
#   adding: generated_images/image_00622.png (stored 0%)
#   adding: generated_images/image_00737.png (stored 0%)
#   adding: generated_images/image_00895.png (stored 0%)
#   adding: generated_images/image_00280.png (stored 0%)
#   adding: generated_images/image_00575.png (stored 0%)
#   adding: generated_images/image_00361.png (deflated 0%)
#   adding: generated_images/image_00834.png (stored 0%)
#   adding: generated_images/image_00507.png (stored 0%)
#   adding: generated_images/image_00077.png (deflated 1%)
#   adding: generated_images/image_00760.png (stored 0%)
#   adding: generated_images/image_00476.png (stored 0%)
#   adding: generated_images/image_00574.png (stored 0%)
#   adding: generated_images/image_00430.png (stored 0%)
#   adding: generated_images/image_00960.png (stored 0%)
#   adding: generated_images/image_00262.png (stored 0%)
#   adding: generated_images/image_00193.png (stored 0%)
#   adding: generated_images/image_00222.png (stored 0%)
#   adding: generated_images/image_00326.png (stored 0%)
#   adding: generated_images/image_00421.png (stored 0%)
#   adding: generated_images/image_00623.png (deflated 0%)
#   adding: generated_images/image_00227.png (deflated 1%)
#   adding: generated_images/image_00638.png (stored 0%)
#   adding: generated_images/image_00552.png (stored 0%)
#   adding: generated_images/image_00854.png (stored 0%)
#   adding: generated_images/image_00872.png (stored 0%)
#   adding: generated_images/image_00679.png (stored 0%)
#   adding: generated_images/image_00076.png (stored 0%)
#   adding: generated_images/image_00904.png (stored 0%)
#   adding: generated_images/image_00766.png (stored 0%)
#   adding: generated_images/image_00149.png (stored 0%)
#   adding: generated_images/image_00971.png (stored 0%)
#   adding: generated_images/image_00054.png (deflated 0%)
#   adding: generated_images/image_00597.png (stored 0%)
#   adding: generated_images/image_00726.png (stored 0%)
#   adding: generated_images/image_00066.png (stored 0%)
#   adding: generated_images/image_00457.png (stored 0%)
#   adding: generated_images/image_00378.png (stored 0%)
#   adding: generated_images/image_00257.png (stored 0%)
#   adding: generated_images/image_00337.png (deflated 2%)
#   adding: generated_images/image_00821.png (stored 0%)
#   adding: generated_images/image_00815.png (stored 0%)
#   adding: generated_images/image_00431.png (stored 0%)
#   adding: generated_images/image_00538.png (stored 0%)
#   adding: generated_images/image_00435.png (stored 0%)
#   adding: generated_images/image_00138.png (stored 0%)
#   adding: generated_images/image_00513.png (stored 0%)
#   adding: generated_images/image_00594.png (stored 0%)
#   adding: generated_images/image_00416.png (stored 0%)
#   adding: generated_images/image_00515.png (stored 0%)
#   adding: generated_images/image_00692.png (stored 0%)
#   adding: generated_images/image_00843.png (stored 0%)
#   adding: generated_images/image_00159.png (deflated 2%)
#   adding: generated_images/image_00219.png (stored 0%)
#   adding: generated_images/image_00789.png (stored 0%)
#   adding: generated_images/image_00451.png (stored 0%)
#   adding: generated_images/image_00201.png (stored 0%)
#   adding: generated_images/image_00973.png (deflated 0%)
#   adding: generated_images/image_00772.png (deflated 1%)
#   adding: generated_images/image_00360.png (deflated 1%)
#   adding: generated_images/image_00067.png (stored 0%)
#   adding: generated_images/image_00927.png (stored 0%)
#   adding: generated_images/image_00669.png (stored 0%)
#   adding: generated_images/image_00718.png (stored 0%)
#   adding: generated_images/image_00809.png (stored 0%)
#   adding: generated_images/image_00953.png (stored 0%)
#   adding: generated_images/image_00651.png (stored 0%)
#   adding: generated_images/image_00930.png (stored 0%)
#   adding: generated_images/image_00585.png (stored 0%)
#   adding: generated_images/image_00681.png (stored 0%)
#   adding: generated_images/image_00650.png (stored 0%)
#   adding: generated_images/image_00041.png (stored 0%)
#   adding: generated_images/image_00728.png (stored 0%)
#   adding: generated_images/image_00380.png (stored 0%)
#   adding: generated_images/image_00983.png (stored 0%)
#   adding: generated_images/image_00235.png (stored 0%)
#   adding: generated_images/image_00088.png (stored 0%)
#   adding: generated_images/image_00242.png (stored 0%)
#   adding: generated_images/image_00248.png (stored 0%)
#   adding: generated_images/image_00137.png (stored 0%)
#   adding: generated_images/image_00324.png (stored 0%)
#   adding: generated_images/image_00314.png (stored 0%)
#   adding: generated_images/image_00116.png (stored 0%)
#   adding: generated_images/image_00446.png (deflated 0%)
#   adding: generated_images/image_00523.png (stored 0%)
#   adding: generated_images/image_00061.png (stored 0%)
#   adding: generated_images/image_00321.png (stored 0%)
#   adding: generated_images/image_00164.png (stored 0%)
#   adding: generated_images/image_00246.png (stored 0%)
#   adding: generated_images/image_00831.png (stored 0%)
#   adding: generated_images/image_00944.png (stored 0%)
#   adding: generated_images/image_00542.png (stored 0%)
#   adding: generated_images/image_00058.png (stored 0%)
#   adding: generated_images/image_00798.png (deflated 1%)
#   adding: generated_images/image_00776.png (stored 0%)
#   adding: generated_images/image_00687.png (stored 0%)
#   adding: generated_images/image_00727.png (stored 0%)
#   adding: generated_images/image_00908.png (stored 0%)
#   adding: generated_images/image_00131.png (stored 0%)
#   adding: generated_images/image_00313.png (stored 0%)
#   adding: generated_images/image_00315.png (stored 0%)
#   adding: generated_images/image_00501.png (stored 0%)
#   adding: generated_images/image_00817.png (deflated 1%)
#   adding: generated_images/image_00060.png (stored 0%)
#   adding: generated_images/image_00489.png (stored 0%)
#   adding: generated_images/image_00885.png (stored 0%)
#   adding: generated_images/image_00696.png (stored 0%)
#   adding: generated_images/image_00302.png (stored 0%)
#   adding: generated_images/image_00741.png (stored 0%)
#   adding: generated_images/image_00179.png (stored 0%)
#   adding: generated_images/image_00654.png (stored 0%)
#   adding: generated_images/image_00982.png (stored 0%)
#   adding: generated_images/image_00172.png (stored 0%)
#   adding: generated_images/image_00928.png (stored 0%)
#   adding: generated_images/image_00064.png (stored 0%)
#   adding: generated_images/image_00849.png (stored 0%)
#   adding: generated_images/image_00610.png (stored 0%)
#   adding: generated_images/image_00030.png (stored 0%)
#   adding: generated_images/image_00733.png (deflated 1%)
#   adding: generated_images/image_00081.png (stored 0%)
#   adding: generated_images/image_00006.png (stored 0%)
#   adding: generated_images/image_00427.png (stored 0%)
#   adding: generated_images/image_00284.png (stored 0%)
#   adding: generated_images/image_00356.png (stored 0%)
#   adding: generated_images/image_00194.png (stored 0%)
#   adding: generated_images/image_00970.png (stored 0%)
#   adding: generated_images/image_00454.png (stored 0%)
#   adding: generated_images/image_00639.png (stored 0%)
#   adding: generated_images/image_00190.png (stored 0%)
#   adding: generated_images/image_00336.png (stored 0%)
#   adding: generated_images/image_00223.png (stored 0%)
#   adding: generated_images/image_00844.png (stored 0%)
#   adding: generated_images/image_00203.png (deflated 1%)
#   adding: generated_images/image_00034.png (deflated 0%)
#   adding: generated_images/image_00583.png (stored 0%)
#   adding: generated_images/image_00498.png (stored 0%)
#   adding: generated_images/image_00032.png (stored 0%)
#   adding: generated_images/image_00129.png (stored 0%)
#   adding: generated_images/image_00168.png (stored 0%)
#   adding: generated_images/image_00506.png (deflated 1%)
#   adding: generated_images/image_00671.png (stored 0%)
#   adding: generated_images/image_00358.png (stored 0%)
#   adding: generated_images/image_00640.png (stored 0%)
#   adding: generated_images/image_00633.png (deflated 2%)
#   adding: generated_images/image_00754.png (stored 0%)
#   adding: generated_images/image_00926.png (stored 0%)
#   adding: generated_images/image_00009.png (stored 0%)
#   adding: generated_images/image_00775.png (stored 0%)
#   adding: generated_images/image_00807.png (stored 0%)
#   adding: generated_images/image_00841.png (stored 0%)
#   adding: generated_images/image_00128.png (stored 0%)
#   adding: generated_images/image_00620.png (stored 0%)
#   adding: generated_images/image_00618.png (stored 0%)
#   adding: generated_images/image_00467.png (stored 0%)
#   adding: generated_images/image_00456.png (stored 0%)
#   adding: generated_images/image_00604.png (stored 0%)
#   adding: generated_images/image_00234.png (stored 0%)
#   adding: generated_images/image_00156.png (stored 0%)
#   adding: generated_images/image_00033.png (stored 0%)
#   adding: generated_images/image_00277.png (stored 0%)
#   adding: generated_images/image_00894.png (stored 0%)
#   adding: generated_images/image_00102.png (stored 0%)
#   adding: generated_images/image_00537.png (stored 0%)
#   adding: generated_images/image_00580.png (stored 0%)
#   adding: generated_images/image_00389.png (stored 0%)
#   adding: generated_images/image_00816.png (stored 0%)
#   adding: generated_images/image_00600.png (stored 0%)
#   adding: generated_images/image_00599.png (stored 0%)
#   adding: generated_images/image_00723.png (deflated 0%)
#   adding: generated_images/image_00022.png (stored 0%)
#   adding: generated_images/image_00167.png (deflated 1%)
#   adding: generated_images/image_00635.png (stored 0%)
#   adding: generated_images/image_00200.png (stored 0%)
#   adding: generated_images/image_00700.png (stored 0%)
#   adding: generated_images/image_00351.png (stored 0%)
#   adding: generated_images/image_00591.png (deflated 0%)
#   adding: generated_images/image_00869.png (stored 0%)
#   adding: generated_images/image_00085.png (stored 0%)
#   adding: generated_images/image_00095.png (stored 0%)
#   adding: generated_images/image_00520.png (stored 0%)
#   adding: generated_images/image_00975.png (stored 0%)
#   adding: generated_images/image_00915.png (stored 0%)
#   adding: generated_images/image_00119.png (stored 0%)
#   adding: generated_images/image_00579.png (stored 0%)
#   adding: generated_images/image_00713.png (stored 0%)
#   adding: generated_images/image_00665.png (stored 0%)
#   adding: generated_images/image_00409.png (stored 0%)
#   adding: generated_images/image_00101.png (stored 0%)
#   adding: generated_images/image_00917.png (stored 0%)
#   adding: generated_images/image_00283.png (stored 0%)
#   adding: generated_images/image_00906.png (stored 0%)
#   adding: generated_images/image_00463.png (stored 0%)
#   adding: generated_images/image_00735.png (deflated 0%)
#   adding: generated_images/image_00001.png (stored 0%)
#   adding: generated_images/image_00899.png (stored 0%)
#   adding: generated_images/image_00065.png (stored 0%)
#   adding: generated_images/image_00039.png (stored 0%)
#   adding: generated_images/image_00886.png (stored 0%)
#   adding: generated_images/image_00043.png (stored 0%)
#   adding: generated_images/image_00992.png (deflated 0%)
#   adding: generated_images/image_00492.png (stored 0%)
#   adding: generated_images/image_00241.png (stored 0%)
#   adding: generated_images/image_00605.png (stored 0%)
#   adding: generated_images/image_00104.png (stored 0%)
#   adding: generated_images/image_00819.png (stored 0%)
#   adding: generated_images/image_00691.png (stored 0%)
#   adding: generated_images/image_00357.png (stored 0%)
#   adding: generated_images/image_00839.png (stored 0%)
#   adding: generated_images/image_00320.png (stored 0%)
#   adding: generated_images/image_00195.png (stored 0%)
#   adding: generated_images/image_00954.png (stored 0%)
#   adding: generated_images/image_00243.png (stored 0%)
#   adding: generated_images/image_00448.png (stored 0%)
#   adding: generated_images/image_00449.png (stored 0%)
#   adding: generated_images/image_00934.png (stored 0%)
#   adding: generated_images/image_00334.png (deflated 2%)
#   adding: generated_images/image_00012.png (stored 0%)
#   adding: generated_images/image_00080.png (stored 0%)
#   adding: generated_images/image_00782.png (stored 0%)
#   adding: generated_images/image_00418.png (stored 0%)
#   adding: generated_images/image_00836.png (stored 0%)
#   adding: generated_images/image_00453.png (stored 0%)
#   adding: generated_images/image_00645.png (deflated 1%)
#   adding: generated_images/image_00480.png (stored 0%)
#   adding: generated_images/image_00152.png (deflated 1%)
#   adding: generated_images/image_00316.png (deflated 1%)
#   adding: generated_images/image_00021.png (stored 0%)
#   adding: generated_images/image_00312.png (stored 0%)
#   adding: generated_images/image_00988.png (stored 0%)
#   adding: generated_images/image_00593.png (deflated 0%)
#   adding: generated_images/image_00237.png (stored 0%)
#   adding: generated_images/image_00240.png (stored 0%)
#   adding: generated_images/image_00892.png (stored 0%)
#   adding: generated_images/image_00910.png (stored 0%)
#   adding: generated_images/image_00847.png (stored 0%)
#   adding: generated_images/image_00581.png (stored 0%)
#   adding: generated_images/image_00270.png (stored 0%)
#   adding: generated_images/image_00046.png (stored 0%)
#   adding: generated_images/image_00333.png (stored 0%)
#   adding: generated_images/image_00710.png (deflated 3%)
#   adding: generated_images/image_00980.png (stored 0%)
#   adding: generated_images/image_00987.png (stored 0%)
#   adding: generated_images/image_00388.png (stored 0%)
#   adding: generated_images/image_00184.png (stored 0%)
#   adding: generated_images/image_00558.png (stored 0%)
#   adding: generated_images/image_00014.png (deflated 0%)
#   adding: generated_images/image_00202.png (stored 0%)
#   adding: generated_images/image_00487.png (stored 0%)
#   adding: generated_images/image_00140.png (deflated 0%)
#   adding: generated_images/image_00497.png (stored 0%)
#   adding: generated_images/image_00340.png (stored 0%)
#   adding: generated_images/image_00502.png (stored 0%)
#   adding: generated_images/image_00253.png (stored 0%)
#   adding: generated_images/image_00732.png (stored 0%)
#   adding: generated_images/image_00531.png (stored 0%)
#   adding: generated_images/image_00976.png (stored 0%)
#   adding: generated_images/image_00978.png (stored 0%)
#   adding: generated_images/image_00419.png (stored 0%)
#   adding: generated_images/image_00747.png (stored 0%)
#   adding: generated_images/image_00783.png (stored 0%)
#   adding: generated_images/image_00897.png (deflated 1%)
#   adding: generated_images/image_00952.png (stored 0%)
#   adding: generated_images/image_00008.png (stored 0%)
#   adding: generated_images/image_00390.png (stored 0%)
#   adding: generated_images/image_00565.png (stored 0%)
#   adding: generated_images/image_00887.png (stored 0%)
#   adding: generated_images/image_00738.png (stored 0%)
#   adding: generated_images/image_00637.png (stored 0%)
#   adding: generated_images/image_00758.png (deflated 2%)
#   adding: generated_images/image_00929.png (stored 0%)
#   adding: generated_images/image_00098.png (stored 0%)
#   adding: generated_images/image_00275.png (stored 0%)
#   adding: generated_images/image_00355.png (stored 0%)
#   adding: generated_images/image_00948.png (stored 0%)
#   adding: generated_images/image_00670.png (stored 0%)
#   adding: generated_images/image_00986.png (stored 0%)
#   adding: generated_images/image_00751.png (stored 0%)
#   adding: generated_images/image_00972.png (stored 0%)
#   adding: generated_images/image_00055.png (stored 0%)
#   adding: generated_images/image_00764.png (stored 0%)
#   adding: generated_images/image_00967.png (deflated 1%)
#   adding: generated_images/image_00619.png (stored 0%)
#   adding: generated_images/image_00966.png (stored 0%)
#   adding: generated_images/image_00228.png (stored 0%)
#   adding: generated_images/image_00962.png (stored 0%)
#   adding: generated_images/image_00225.png (stored 0%)
#   adding: generated_images/image_00912.png (stored 0%)
#   adding: generated_images/image_00946.png (stored 0%)
#   adding: generated_images/image_00290.png (stored 0%)
#   adding: generated_images/image_00307.png (deflated 1%)
#   adding: generated_images/image_00749.png (stored 0%)
#   adding: generated_images/image_00221.png (stored 0%)
#   adding: generated_images/image_00349.png (stored 0%)
#   adding: generated_images/image_00114.png (stored 0%)
#   adding: generated_images/image_00709.png (stored 0%)
#   adding: generated_images/image_00015.png (stored 0%)
#   adding: generated_images/image_00562.png (stored 0%)
#   adding: generated_images/image_00932.png (stored 0%)
#   adding: generated_images/image_00424.png (stored 0%)
#   adding: generated_images/image_00813.png (deflated 1%)
#   adding: generated_images/image_00165.png (stored 0%)
#   adding: generated_images/image_00437.png (stored 0%)
#   adding: generated_images/image_00484.png (stored 0%)
#   adding: generated_images/image_00469.png (stored 0%)
#   adding: generated_images/image_00224.png (stored 0%)
#   adding: generated_images/image_00444.png (stored 0%)
#   adding: generated_images/image_00215.png (stored 0%)
#   adding: generated_images/image_00296.png (stored 0%)
#   adding: generated_images/image_00432.png (stored 0%)
#   adding: generated_images/image_00884.png (stored 0%)
#   adding: generated_images/image_00206.png (stored 0%)
#   adding: generated_images/image_00704.png (stored 0%)
#   adding: generated_images/image_00318.png (stored 0%)
#   adding: generated_images/image_00020.png (stored 0%)
#   adding: generated_images/image_00288.png (stored 0%)
#   adding: generated_images/image_00907.png (stored 0%)
#   adding: generated_images/image_00613.png (stored 0%)
#   adding: generated_images/image_00875.png (stored 0%)
#   adding: generated_images/image_00702.png (stored 0%)
#   adding: generated_images/image_00400.png (stored 0%)
#   adding: generated_images/image_00503.png (stored 0%)
#   adding: generated_images/image_00144.png (stored 0%)
#   adding: generated_images/image_00526.png (stored 0%)
#   adding: generated_images/image_00786.png (stored 0%)
#   adding: generated_images/image_00800.png (stored 0%)
#   adding: generated_images/image_00919.png (stored 0%)
#   adding: generated_images/image_00267.png (deflated 1%)
#   adding: generated_images/image_00510.png (stored 0%)
#   adding: generated_images/image_00226.png (deflated 2%)
#   adding: generated_images/image_00121.png (stored 0%)
#   adding: generated_images/image_00999.png (stored 0%)
#   adding: generated_images/image_00842.png (stored 0%)
#   adding: generated_images/image_00367.png (stored 0%)
#   adding: generated_images/image_00890.png (stored 0%)
#   adding: generated_images/image_00771.png (stored 0%)
#   adding: generated_images/image_00158.png (stored 0%)
#   adding: generated_images/image_00145.png (stored 0%)
#   adding: generated_images/image_00091.png (stored 0%)
#   adding: generated_images/image_00852.png (stored 0%)
#   adding: generated_images/image_00867.png (stored 0%)
#   adding: generated_images/image_00414.png (stored 0%)
#   adding: generated_images/image_00301.png (stored 0%)
#   adding: generated_images/image_00415.png (stored 0%)
#   adding: generated_images/image_00940.png (deflated 2%)
#   adding: generated_images/image_00959.png (stored 0%)
#   adding: generated_images/image_00325.png (deflated 2%)
#   adding: generated_images/image_00628.png (stored 0%)
#   adding: generated_images/image_00509.png (stored 0%)
#   adding: generated_images/image_00805.png (deflated 3%)
#   adding: generated_images/image_00685.png (deflated 2%)
#   adding: generated_images/image_00792.png (deflated 1%)
#   adding: generated_images/image_00124.png (stored 0%)
#   adding: generated_images/image_00070.png (stored 0%)
#   adding: generated_images/image_00774.png (deflated 0%)
#   adding: generated_images/image_00108.png (stored 0%)
#   adding: generated_images/image_00115.png (stored 0%)
#   adding: generated_images/image_00868.png (deflated 2%)
#   adding: generated_images/image_00769.png (stored 0%)
#   adding: generated_images/image_00377.png (stored 0%)
#   adding: generated_images/image_00244.png (deflated 1%)
#   adding: generated_images/image_00949.png (stored 0%)
#   adding: generated_images/image_00466.png (stored 0%)
#   adding: generated_images/image_00051.png (stored 0%)
#   adding: generated_images/image_00263.png (stored 0%)
#   adding: generated_images/image_00232.png (stored 0%)
#   adding: generated_images/image_00699.png (stored 0%)
#   adding: generated_images/image_00922.png (stored 0%)
#   adding: generated_images/image_00392.png (stored 0%)
#   adding: generated_images/image_00914.png (stored 0%)
#   adding: generated_images/image_00208.png (stored 0%)
#   adding: generated_images/image_00828.png (stored 0%)
#   adding: generated_images/image_00352.png (deflated 1%)
#   adding: generated_images/image_00297.png (stored 0%)
#   adding: generated_images/image_00238.png (stored 0%)
#   adding: generated_images/image_00174.png (stored 0%)
#   adding: generated_images/image_00678.png (stored 0%)
#   adding: generated_images/image_00099.png (stored 0%)
#   adding: generated_images/image_00459.png (deflated 2%)
#   adding: generated_images/image_00479.png (stored 0%)
#   adding: generated_images/image_00330.png (stored 0%)
#   adding: generated_images/image_00913.png (stored 0%)
#   adding: generated_images/image_00793.png (stored 0%)
#   adding: generated_images/image_00686.png (deflated 1%)
#   adding: generated_images/image_00963.png (stored 0%)
#   adding: generated_images/image_00548.png (stored 0%)
#   adding: generated_images/image_00712.png (stored 0%)
#   adding: generated_images/image_00864.png (stored 0%)
#   adding: generated_images/image_00322.png (stored 0%)
#   adding: generated_images/image_00905.png (stored 0%)
#   adding: generated_images/image_00374.png (deflated 0%)
#   adding: generated_images/image_00716.png (stored 0%)
#   adding: generated_images/image_00016.png (stored 0%)
#   adding: generated_images/image_00745.png (stored 0%)
#   adding: generated_images/image_00399.png (deflated 1%)
#   adding: generated_images/image_00231.png (stored 0%)
#   adding: generated_images/image_00647.png (deflated 1%)
#   adding: generated_images/image_00863.png (stored 0%)
#   adding: generated_images/image_00205.png (deflated 1%)
#   adding: generated_images/image_00308.png (stored 0%)
#   adding: generated_images/image_00615.png (stored 0%)
#   adding: generated_images/image_00993.png (stored 0%)
#   adding: generated_images/image_00441.png (stored 0%)
#   adding: generated_images/image_00801.png (stored 0%)
#   adding: generated_images/image_00096.png (stored 0%)
#   adding: generated_images/image_00490.png (stored 0%)
#   adding: generated_images/image_00748.png (stored 0%)
#   adding: generated_images/image_00851.png (stored 0%)
#   adding: generated_images/image_00239.png (stored 0%)
#   adding: generated_images/image_00109.png (stored 0%)
#   adding: generated_images/image_00763.png (stored 0%)
#   adding: generated_images/image_00425.png (stored 0%)
#   adding: generated_images/image_00382.png (deflated 2%)
#   adding: generated_images/image_00279.png (stored 0%)
#   adding: generated_images/image_00465.png (stored 0%)
#   adding: generated_images/image_00714.png (stored 0%)
#   adding: generated_images/image_00979.png (stored 0%)
#   adding: generated_images/image_00373.png (stored 0%)
#   adding: generated_images/image_00460.png (deflated 1%)
#   adding: generated_images/image_00462.png (stored 0%)
#   adding: generated_images/image_00426.png (stored 0%)
#   adding: generated_images/image_00818.png (stored 0%)
#   adding: generated_images/image_00803.png (stored 0%)
#   adding: generated_images/image_00578.png (stored 0%)
#   adding: generated_images/image_00148.png (deflated 1%)
#   adding: generated_images/image_00663.png (stored 0%)
#   adding: generated_images/image_00282.png (stored 0%)
#   adding: generated_images/image_00880.png (stored 0%)
#   adding: generated_images/image_00572.png (stored 0%)
#   adding: generated_images/image_00293.png (stored 0%)
#   adding: generated_images/image_00317.png (stored 0%)
#   adding: generated_images/image_00495.png (stored 0%)
#   adding: generated_images/image_00491.png (stored 0%)
#   adding: generated_images/image_00211.png (stored 0%)
#   adding: generated_images/image_00564.png (stored 0%)
#   adding: generated_images/image_00019.png (stored 0%)
#   adding: generated_images/image_00464.png (stored 0%)
#   adding: generated_images/image_00701.png (stored 0%)
#   adding: generated_images/image_00335.png (stored 0%)
#   adding: generated_images/image_00649.png (stored 0%)
#   adding: generated_images/image_00087.png (stored 0%)
#   adding: generated_images/image_00375.png (stored 0%)
#   adding: generated_images/image_00345.png (stored 0%)
#   adding: generated_images/image_00372.png (stored 0%)
#   adding: generated_images/image_00855.png (deflated 1%)
#   adding: generated_images/image_00505.png (stored 0%)
#   adding: generated_images/image_00504.png (stored 0%)
#   adding: generated_images/image_00825.png (stored 0%)
#   adding: generated_images/image_00923.png (stored 0%)
#   adding: generated_images/image_00461.png (stored 0%)
#   adding: generated_images/image_00820.png (stored 0%)
#   adding: generated_images/image_00401.png (stored 0%)
#   adding: generated_images/image_00778.png (deflated 1%)
#   adding: generated_images/image_00664.png (deflated 0%)
#   adding: generated_images/image_00366.png (stored 0%)
#   adding: generated_images/image_00937.png (stored 0%)
#   adding: generated_images/image_00862.png (stored 0%)
#   adding: generated_images/image_00743.png (stored 0%)
#   adding: generated_images/image_00955.png (stored 0%)
#   adding: generated_images/image_00299.png (stored 0%)
#   adding: generated_images/image_00093.png (deflated 2%)
#   adding: generated_images/image_00697.png (stored 0%)
#   adding: generated_images/image_00938.png (stored 0%)
#   adding: generated_images/image_00832.png (stored 0%)
#   adding: generated_images/image_00123.png (deflated 0%)
#   adding: generated_images/image_00472.png (stored 0%)
#   adding: generated_images/image_00916.png (stored 0%)
#   adding: generated_images/image_00846.png (stored 0%)
#   adding: generated_images/image_00139.png (stored 0%)
#   adding: generated_images/image_00969.png (stored 0%)
#   adding: generated_images/image_00113.png (stored 0%)
#   adding: generated_images/image_00062.png (stored 0%)
#   adding: generated_images/image_00294.png (stored 0%)
#   adding: generated_images/image_00068.png (stored 0%)
#   adding: generated_images/image_00171.png (stored 0%)
#   adding: generated_images/image_00344.png (stored 0%)
#   adding: generated_images/image_00258.png (stored 0%)
#   adding: generated_images/image_00407.png (stored 0%)
#   adding: generated_images/image_00632.png (stored 0%)
#   adding: generated_images/image_00417.png (stored 0%)
#   adding: generated_images/image_00166.png (stored 0%)
#   adding: generated_images/image_00596.png (deflated 2%)
#   adding: generated_images/image_00398.png (stored 0%)
#   adding: generated_images/image_00013.png (stored 0%)
#   adding: generated_images/image_00136.png (deflated 1%)
#   adding: generated_images/image_00568.png (stored 0%)
#   adding: generated_images/image_00806.png (stored 0%)
#   adding: generated_images/image_00653.png (deflated 0%)
#   adding: generated_images/image_00188.png (stored 0%)
#   adding: generated_images/image_00544.png (stored 0%)
#   adding: generated_images/image_00720.png (stored 0%)
#   adding: generated_images/image_00998.png (stored 0%)
#   adding: generated_images/image_00406.png (stored 0%)
#   adding: generated_images/image_00359.png (stored 0%)
#   adding: generated_images/image_00848.png (stored 0%)
#   adding: generated_images/image_00902.png (stored 0%)
#   adding: generated_images/image_00753.png (stored 0%)
#   adding: generated_images/image_00362.png (stored 0%)
#   adding: generated_images/image_00272.png (stored 0%)
#   adding: generated_images/image_00126.png (stored 0%)
#   adding: generated_images/image_00370.png (deflated 0%)
#   adding: generated_images/image_00391.png (stored 0%)
#   adding: generated_images/image_00634.png (stored 0%)
#   adding: generated_images/image_00534.png (stored 0%)
#   adding: generated_images/image_00289.png (stored 0%)
#   adding: generated_images/image_00779.png (stored 0%)
#   adding: generated_images/image_00291.png (stored 0%)
#   adding: generated_images/image_00433.png (stored 0%)
#   adding: generated_images/image_00365.png (stored 0%)
#   adding: generated_images/image_00395.png (stored 0%)
#   adding: generated_images/image_00089.png (stored 0%)
#   adding: generated_images/image_00535.png (deflated 0%)
#   adding: generated_images/image_00641.png (stored 0%)
#   adding: generated_images/image_00192.png (stored 0%)
#   adding: generated_images/image_00118.png (stored 0%)
#   adding: generated_images/image_00882.png (stored 0%)
#   adding: generated_images/image_00059.png (deflated 1%)
#   adding: generated_images/image_00025.png (stored 0%)
#   adding: generated_images/image_00342.png (stored 0%)
#   adding: generated_images/image_00183.png (stored 0%)
#   adding: generated_images/image_00873.png (stored 0%)
#   adding: generated_images/image_00181.png (stored 0%)
#   adding: generated_images/image_00947.png (stored 0%)
#   adding: generated_images/image_00655.png (deflated 1%)
#   adding: generated_images/image_00310.png (stored 0%)
#   adding: generated_images/image_00543.png (stored 0%)
#   adding: generated_images/image_00759.png (stored 0%)
#   adding: generated_images/image_00286.png (deflated 1%)
#   adding: generated_images/image_00247.png (stored 0%)
#   adding: generated_images/image_00874.png (stored 0%)
#   adding: generated_images/image_00888.png (stored 0%)
#   adding: generated_images/image_00721.png (deflated 0%)
#   adding: generated_images/image_00273.png (stored 0%)
#   adding: generated_images/image_00442.png (stored 0%)
#   adding: generated_images/image_00403.png (stored 0%)
#   adding: generated_images/image_00951.png (stored 0%)
#   adding: generated_images/image_00468.png (stored 0%)
#   adding: generated_images/image_00083.png (stored 0%)
#   adding: generated_images/image_00739.png (stored 0%)
#   adding: generated_images/image_00621.png (stored 0%)
#   adding: generated_images/image_00175.png (stored 0%)
#   adding: generated_images/image_00898.png (stored 0%)
#   adding: generated_images/image_00942.png (stored 0%)
#   adding: generated_images/image_00455.png (stored 0%)
#   adding: generated_images/image_00958.png (stored 0%)
#   adding: generated_images/image_00768.png (stored 0%)
#   adding: generated_images/image_00777.png (deflated 2%)
#   adding: generated_images/image_00658.png (stored 0%)
#   adding: generated_images/image_00567.png (stored 0%)
#   adding: generated_images/image_00871.png (stored 0%)
#   adding: generated_images/image_00598.png (stored 0%)
#   adding: generated_images/image_00746.png (stored 0%)
#   adding: generated_images/image_00420.png (stored 0%)
#   adding: generated_images/image_00265.png (deflated 1%)
#   adding: generated_images/image_00130.png (stored 0%)
#   adding: generated_images/image_00920.png (stored 0%)
#   adding: generated_images/image_00857.png (stored 0%)
#   adding: generated_images/image_00762.png (stored 0%)
#   adding: generated_images/image_00584.png (stored 0%)
#   adding: generated_images/image_00703.png (stored 0%)
#   adding: generated_images/image_00939.png (deflated 1%)
#   adding: generated_images/image_00566.png (deflated 1%)
#   adding: generated_images/image_00611.png (deflated 0%)
#   adding: generated_images/image_00477.png (stored 0%)
#   adding: generated_images/image_00811.png (stored 0%)
#   adding: generated_images/image_00592.png (deflated 3%)
#   adding: generated_images/image_00404.png (stored 0%)
#   adding: generated_images/image_00646.png (stored 0%)
#   adding: generated_images/image_00590.png (stored 0%)
#   adding: generated_images/image_00990.png (stored 0%)
#   adding: generated_images/image_00676.png (stored 0%)
#   adding: generated_images/image_00338.png (stored 0%)
#   adding: generated_images/image_00411.png (deflated 0%)
#   adding: generated_images/image_00125.png (stored 0%)
#   adding: generated_images/image_00561.png (stored 0%)
#   adding: generated_images/image_00305.png (stored 0%)
#   adding: generated_images/image_00719.png (stored 0%)
#   adding: generated_images/image_00725.png (stored 0%)
#   adding: generated_images/image_00111.png (stored 0%)
#   adding: generated_images/image_00508.png (stored 0%)
#   adding: generated_images/image_00693.png (stored 0%)
#   adding: generated_images/image_00142.png (stored 0%)
#   adding: generated_images/image_00903.png (deflated 1%)
#   adding: generated_images/image_00187.png (stored 0%)
#   adding: generated_images/image_00483.png (stored 0%)
#   adding: generated_images/image_00829.png (stored 0%)
#   adding: generated_images/image_00180.png (stored 0%)
#   adding: generated_images/image_00889.png (stored 0%)
#   adding: generated_images/image_00151.png (stored 0%)
#   adding: generated_images/image_00981.png (deflated 0%)
#   adding: generated_images/image_00110.png (stored 0%)
#   adding: generated_images/image_00715.png (stored 0%)
#   adding: generated_images/image_00788.png (stored 0%)
#   adding: generated_images/image_00086.png (deflated 0%)
#   adding: generated_images/image_00412.png (stored 0%)
#   adding: generated_images/image_00706.png (stored 0%)
#   adding: generated_images/image_00770.png (stored 0%)
#   adding: generated_images/image_00339.png (stored 0%)
#   adding: generated_images/image_00005.png (stored 0%)
#   adding: generated_images/image_00371.png (deflated 1%)
#   adding: generated_images/image_00648.png (deflated 2%)
#   adding: generated_images/image_00830.png (stored 0%)
#   adding: generated_images/image_00688.png (stored 0%)
#   adding: generated_images/image_00052.png (stored 0%)
#   adding: generated_images/image_00471.png (stored 0%)
#   adding: generated_images/image_00797.png (deflated 2%)
#   adding: generated_images/image_00379.png (deflated 2%)
#   adding: generated_images/image_00555.png (stored 0%)
#   adding: generated_images/image_00050.png (stored 0%)
#   adding: generated_images/image_00901.png (deflated 1%)
#   adding: generated_images/image_00840.png (stored 0%)
#   adding: generated_images/image_00810.png (deflated 1%)
#   adding: generated_images/image_00218.png (stored 0%)
#   adding: generated_images/image_00569.png (stored 0%)
#   adding: generated_images/image_00306.png (stored 0%)
#   adding: generated_images/image_00833.png (stored 0%)
#   adding: generated_images/image_00097.png (stored 0%)
#   adding: generated_images/image_00381.png (stored 0%)
#   adding: generated_images/image_00450.png (stored 0%)
#   adding: generated_images/image_00154.png (stored 0%)
#   adding: generated_images/image_00956.png (deflated 1%)
#   adding: generated_images/image_00736.png (stored 0%)
#   adding: generated_images/image_00163.png (stored 0%)
#   adding: generated_images/image_00595.png (stored 0%)
#   adding: generated_images/image_00185.png (stored 0%)
#   adding: generated_images/image_00024.png (stored 0%)
#   adding: generated_images/image_00017.png (stored 0%)
#   adding: generated_images/image_00170.png (stored 0%)
#   adding: generated_images/image_00266.png (stored 0%)
#   adding: generated_images/image_00363.png (stored 0%)
#   adding: generated_images/image_00268.png (stored 0%)
#   adding: generated_images/image_00761.png (stored 0%)
#   adding: generated_images/image_00328.png (stored 0%)
#   adding: generated_images/image_00261.png (stored 0%)
#   adding: generated_images/image_00133.png (stored 0%)
#   adding: generated_images/image_00546.png (stored 0%)
#   adding: generated_images/image_00036.png (stored 0%)
#   adding: generated_images/image_00150.png (stored 0%)
#   adding: generated_images/image_00668.png (deflated 1%)
#   adding: generated_images/image_00722.png (stored 0%)
#   adding: generated_images/image_00023.png (stored 0%)
#   adding: generated_images/image_00117.png (deflated 0%)
#   adding: generated_images/image_00824.png (stored 0%)
#   adding: generated_images/image_00300.png (stored 0%)
#   adding: generated_images/image_00933.png (stored 0%)
#   adding: generated_images/image_00850.png (deflated 2%)
#   adding: generated_images/image_00196.png (stored 0%)
#   adding: generated_images/image_00674.png (stored 0%)
#   adding: generated_images/image_00295.png (stored 0%)
#   adding: generated_images/image_00756.png (deflated 1%)
#   adding: generated_images/image_00387.png (stored 0%)
#   adding: generated_images/image_00011.png (stored 0%)
#   adding: generated_images/image_00985.png (stored 0%)
#   adding: generated_images/image_00147.png (stored 0%)
#   adding: generated_images/image_00744.png (stored 0%)
#   adding: generated_images/image_00394.png (stored 0%)
#   adding: generated_images/image_00157.png (stored 0%)
#   adding: generated_images/image_00731.png (deflated 2%)
#   adding: generated_images/image_00879.png (deflated 0%)
#   adding: generated_images/image_00035.png (stored 0%)
#   adding: generated_images/image_00767.png (stored 0%)
#   adding: generated_images/image_00105.png (stored 0%)
#   adding: generated_images/image_00347.png (stored 0%)
#   adding: generated_images/image_00049.png (deflated 1%)
#   adding: generated_images/image_00989.png (stored 0%)
#   adding: generated_images/image_00210.png (stored 0%)
#   adding: generated_images/image_00796.png (stored 0%)
#   adding: generated_images/image_00656.png (deflated 1%)
#   adding: generated_images/image_00945.png (stored 0%)
#   adding: generated_images/image_00071.png (stored 0%)
#   adding: generated_images/image_00554.png (stored 0%)
#   adding: generated_images/image_00859.png (stored 0%)
#   adding: generated_images/image_00630.png (stored 0%)
#   adding: generated_images/image_00422.png (stored 0%)
#   adding: generated_images/image_00773.png (stored 0%)
#   adding: generated_images/image_00438.png (deflated 1%)
#   adding: generated_images/image_00285.png (stored 0%)
#   adding: generated_images/image_00570.png (stored 0%)
#   adding: generated_images/image_00311.png (stored 0%)
#   adding: generated_images/image_00539.png (deflated 1%)
#   adding: generated_images/image_00169.png (stored 0%)
#   adding: generated_images/image_00092.png (stored 0%)
#   adding: generated_images/image_00711.png (stored 0%)
#   adding: generated_images/image_00936.png (stored 0%)
#   adding: generated_images/image_00909.png (stored 0%)
#   adding: generated_images/image_00499.png (stored 0%)
#   adding: generated_images/image_00695.png (stored 0%)
#   adding: generated_images/image_00974.png (stored 0%)
#   adding: generated_images/image_00860.png (stored 0%)
#   adding: generated_images/image_00672.png (stored 0%)
#   adding: generated_images/image_00160.png (stored 0%)
#   adding: generated_images/image_00603.png (stored 0%)
#   adding: generated_images/image_00921.png (stored 0%)
#   adding: generated_images/image_00079.png (deflated 1%)
#   adding: generated_images/image_00191.png (stored 0%)
#   adding: generated_images/image_00624.png (stored 0%)
#   adding: generated_images/image_00662.png (stored 0%)
#   adding: generated_images/image_00601.png (stored 0%)
#   adding: generated_images/image_00207.png (stored 0%)
#   adding: generated_images/image_00122.png (stored 0%)
#   adding: generated_images/image_00984.png (stored 0%)
#   adding: generated_images/image_00652.png (stored 0%)
#   adding: generated_images/image_00545.png (stored 0%)
#   adding: generated_images/image_00384.png (stored 0%)
#   adding: generated_images/image_00631.png (stored 0%)
#   adding: generated_images/image_00968.png (deflated 1%)
#   adding: generated_images/image_00559.png (stored 0%)
#   adding: generated_images/image_00609.png (stored 0%)
#   adding: generated_images/image_00657.png (stored 0%)
#   adding: generated_images/image_00493.png (stored 0%)
#   adding: generated_images/image_00252.png (stored 0%)
#   adding: generated_images/image_00197.png (stored 0%)
#   adding: generated_images/image_00689.png (stored 0%)
#   adding: generated_images/image_00517.png (stored 0%)
#   adding: generated_images/image_00614.png (deflated 1%)
#   adding: generated_images/image_00037.png (stored 0%)
#   adding: generated_images/image_00153.png (stored 0%)
#   adding: generated_images/image_00189.png (stored 0%)
#   adding: generated_images/image_00481.png (stored 0%)
#   adding: generated_images/image_00309.png (stored 0%)
#   adding: generated_images/image_00694.png (stored 0%)
#   adding: generated_images/image_00353.png (stored 0%)
#   adding: generated_images/image_00063.png (stored 0%)
#   adding: generated_images/image_00705.png (stored 0%)
#   adding: generated_images/image_00644.png (stored 0%)
#   adding: generated_images/image_00393.png (deflated 1%)
#   adding: generated_images/image_00486.png (stored 0%)
#   adding: generated_images/image_00132.png (stored 0%)
#   adding: generated_images/image_00332.png (stored 0%)
#   adding: generated_images/image_00434.png (stored 0%)
#   adding: generated_images/image_00997.png (stored 0%)
#   adding: generated_images/image_00690.png (stored 0%)
#   adding: generated_images/image_00405.png (stored 0%)
#   adding: generated_images/image_00589.png (stored 0%)
#   adding: generated_images/image_00876.png (stored 0%)
#   adding: generated_images/image_00236.png (stored 0%)
#   adding: generated_images/image_00233.png (stored 0%)
#   adding: generated_images/image_00911.png (deflated 2%)
#   adding: generated_images/image_00612.png (stored 0%)
#   adding: generated_images/image_00000.png (stored 0%)
#   adding: generated_images/image_00740.png (stored 0%)
#   adding: generated_images/image_00996.png (stored 0%)
#   adding: generated_images/image_00556.png (stored 0%)
#   adding: generated_images/image_00877.png (stored 0%)
#   adding: generated_images/image_00780.png (stored 0%)
#   adding: generated_images/image_00661.png (stored 0%)
#   adding: generated_images/image_00002.png (stored 0%)
#   adding: generated_images/image_00991.png (deflated 2%)
#   adding: generated_images/image_00447.png (stored 0%)
#   adding: generated_images/image_00216.png (stored 0%)
#   adding: generated_images/image_00626.png (stored 0%)
#   adding: generated_images/image_00485.png (stored 0%)
#   adding: generated_images/image_00536.png (stored 0%)
#   adding: generated_images/image_00329.png (stored 0%)
#   adding: generated_images/image_00386.png (stored 0%)
#   adding: generated_images/image_00106.png (stored 0%)
#   adding: generated_images/image_00804.png (stored 0%)
#   adding: generated_images/image_00385.png (stored 0%)
#   adding: generated_images/image_00094.png (stored 0%)
#   adding: generated_images/image_00659.png (stored 0%)
#   adding: generated_images/image_00445.png (stored 0%)
#   adding: generated_images/image_00482.png (stored 0%)
#   adding: generated_images/image_00781.png (stored 0%)
#   adding: generated_images/image_00547.png (stored 0%)
#   adding: generated_images/image_00765.png (stored 0%)
#   adding: generated_images/image_00608.png (stored 0%)
#   adding: generated_images/image_00287.png (stored 0%)
#   adding: generated_images/image_00048.png (stored 0%)
#   adding: generated_images/image_00752.png (stored 0%)
#   adding: generated_images/image_00112.png (stored 0%)
#   adding: generated_images/image_00550.png (stored 0%)
#   adding: generated_images/image_00822.png (stored 0%)
#   adding: generated_images/image_00496.png (stored 0%)
#   adding: generated_images/image_00161.png (stored 0%)
#   adding: generated_images/image_00031.png (stored 0%)
#   adding: generated_images/image_00274.png (deflated 1%)
#   adding: generated_images/image_00957.png (stored 0%)
#   adding: generated_images/image_00127.png (stored 0%)
#   adding: generated_images/image_00666.png (stored 0%)
#   adding: generated_images/image_00230.png (deflated 1%)
#   adding: generated_images/image_00298.png (stored 0%)
#   adding: generated_images/image_00808.png (stored 0%)
#   adding: generated_images/image_00255.png (stored 0%)
#   adding: generated_images/image_00660.png (stored 0%)
#   adding: generated_images/image_00186.png (stored 0%)
#   adding: generated_images/image_00881.png (deflated 2%)
#   adding: generated_images/image_00047.png (stored 0%)
#   adding: generated_images/image_00827.png (stored 0%)
#   adding: generated_images/image_00056.png (stored 0%)
#   adding: generated_images/image_00518.png (stored 0%)
#   adding: generated_images/image_00541.png (stored 0%)
#   adding: generated_images/image_00042.png (stored 0%)
#   adding: generated_images/image_00004.png (stored 0%)
#   adding: generated_images/image_00943.png (stored 0%)
#   adding: generated_images/image_00018.png (stored 0%)
#   adding: generated_images/image_00413.png (stored 0%)
#   adding: generated_images/image_00925.png (stored 0%)
#   adding: generated_images/image_00587.png (stored 0%)
#   adding: generated_images/image_00026.png (deflated 2%)
#   adding: generated_images/image_00213.png (stored 0%)
#   adding: generated_images/image_00458.png (stored 0%)
#   adding: generated_images/image_00053.png (stored 0%)
#   adding: generated_images/image_00090.png (stored 0%)
#   adding: generated_images/image_00553.png (stored 0%)
#   adding: generated_images/image_00368.png (stored 0%)
#   adding: generated_images/image_00323.png (stored 0%)
#   adding: generated_images/image_00675.png (stored 0%)
#   adding: generated_images/image_00220.png (stored 0%)
#   adding: generated_images/image_00003.png (deflated 0%)
#   adding: generated_images/image_00249.png (stored 0%)
#   adding: generated_images/image_00682.png (stored 0%)
#   adding: generated_images/image_00173.png (stored 0%)
#   adding: generated_images/image_00636.png (deflated 1%)
#   adding: generated_images/image_00576.png (stored 0%)
#   adding: generated_images/image_00787.png (deflated 2%)
#   adding: generated_images/image_00791.png (deflated 0%)
#   adding: generated_images/image_00134.png (stored 0%)
#   adding: generated_images/image_00369.png (deflated 1%)
#   adding: generated_images/image_00865.png (stored 0%)
#   adding: generated_images/image_00217.png (stored 0%)
#   adding: generated_images/image_00582.png (deflated 1%)
#   adding: generated_images/image_00717.png (deflated 3%)
#   adding: generated_images/image_00350.png (stored 0%)
#   adding: generated_images/image_00524.png (stored 0%)
#   adding: generated_images/image_00512.png (stored 0%)
#   adding: generated_images/image_00560.png (stored 0%)
#   adding: generated_images/image_00802.png (deflated 1%)
#   adding: generated_images/image_00245.png (deflated 1%)
#   adding: generated_images/image_00269.png (stored 0%)
#   adding: generated_images/image_00606.png (stored 0%)
#   adding: generated_images/image_00396.png (stored 0%)
#   adding: generated_images/image_00514.png (stored 0%)
#   adding: generated_images/image_00303.png (stored 0%)
#   adding: generated_images/image_00029.png (stored 0%)
#   adding: generated_images/image_00045.png (deflated 0%)
#   adding: generated_images/image_00667.png (stored 0%)
#   adding: generated_images/image_00866.png (stored 0%)
#   adding: generated_images/image_00530.png (stored 0%)
#   adding: generated_images/image_00044.png (stored 0%)
#   adding: generated_images/image_00010.png (stored 0%)
#   adding: generated_images/image_00423.png (stored 0%)
#   adding: generated_images/image_00563.png (deflated 0%)
#   adding: generated_images/image_00673.png (stored 0%)
#   adding: generated_images/image_00525.png (stored 0%)
#   adding: generated_images/image_00540.png (stored 0%)
#   adding: generated_images/image_00376.png (stored 0%)
#   adding: generated_images/image_00551.png (stored 0%)
#   adding: generated_images/image_00331.png (stored 0%)
#   adding: generated_images/image_00073.png (stored 0%)
#   adding: generated_images/image_00799.png (stored 0%)
#   adding: generated_images/image_00141.png (stored 0%)
#   adding: generated_images/image_00204.png (stored 0%)
#   adding: generated_images/image_00893.png (stored 0%)
#   adding: generated_images/image_00028.png (stored 0%)
#   adding: generated_images/image_00521.png (stored 0%)
#   adding: generated_images/image_00750.png (stored 0%)
#   adding: generated_images/image_00918.png (stored 0%)
#   adding: generated_images/image_00794.png (stored 0%)
#   adding: generated_images/image_00698.png (stored 0%)
#   adding: generated_images/image_00176.png (stored 0%)
#   adding: generated_images/image_00790.png (stored 0%)
#   adding: generated_images/image_00354.png (stored 0%)
#   adding: generated_images/image_00178.png (stored 0%)
#   adding: generated_images/image_00199.png (stored 0%)
#   adding: generated_images/image_00439.png (stored 0%)
#   adding: generated_images/image_00977.png (stored 0%)
#   adding: generated_images/image_00729.png (deflated 2%)
#   adding: generated_images/image_00730.png (stored 0%)
#   adding: generated_images/image_00364.png (stored 0%)
#   adding: generated_images/image_00057.png (stored 0%)
#   adding: generated_images/image_00410.png (stored 0%)
#   adding: generated_images/image_00281.png (stored 0%)
#   adding: generated_images/image_00440.png (stored 0%)
#   adding: generated_images/image_00994.png (stored 0%)
#   adding: generated_images/image_00795.png (stored 0%)
#   adding: generated_images/image_00965.png (stored 0%)
#   adding: generated_images/image_00532.png (stored 0%)
#   adding: generated_images/image_00883.png (deflated 0%)
#   adding: generated_images/image_00643.png (stored 0%)
#   adding: generated_images/image_00516.png (stored 0%)
#   adding: generated_images/image_00341.png (stored 0%)
#   adding: generated_images/image_00027.png (stored 0%)
#   adding: generated_images/image_00100.png (stored 0%)
#   adding: generated_images/image_00443.png (stored 0%)
#   adding: generated_images/image_00428.png (stored 0%)
#   adding: generated_images/image_00343.png (stored 0%)
#   adding: generated_images/image_00856.png (stored 0%)
#   adding: generated_images/image_00588.png (stored 0%)
#   adding: generated_images/image_00120.png (deflated 1%)
#   adding: generated_images/image_00724.png (stored 0%)
#   adding: generated_images/image_00571.png (stored 0%)
#   adding: generated_images/image_00577.png (stored 0%)
#   adding: generated_images/image_00276.png (stored 0%)
#   adding: generated_images/image_00209.png (stored 0%)
#   adding: generated_images/image_00383.png (stored 0%)
#   adding: generated_images/image_00264.png (stored 0%)
#   adding: generated_images/image_00826.png (stored 0%)
#   adding: generated_images/image_00680.png (stored 0%)
#   adding: generated_images/image_00182.png (stored 0%)
#   adding: generated_images/image_00162.png (stored 0%)
#   adding: generated_images/image_00470.png (stored 0%)
#   adding: generated_images/image_00995.png (stored 0%)
#   adding: generated_images/image_00684.png (stored 0%)
#   adding: generated_images/image_00251.png (stored 0%)
#   adding: generated_images/image_00212.png (stored 0%)
#   adding: generated_images/image_00785.png (stored 0%)
#   adding: generated_images/image_00271.png (stored 0%)
#   adding: generated_images/image_00007.png (stored 0%)
#   adding: generated_images/image_00812.png (stored 0%)
#   adding: generated_images/image_00858.png (stored 0%)
#   adding: generated_images/image_00742.png (stored 0%)
#   adding: generated_images/image_00082.png (deflated 2%)
#   adding: generated_images/image_00838.png (stored 0%)
#   adding: generated_images/image_00402.png (stored 0%)
#   adding: generated_images/image_00254.png (stored 0%)
#   adding: generated_images/image_00837.png (stored 0%)
#   adding: generated_images/image_00878.png (stored 0%)
#   adding: generated_images/image_00607.png (stored 0%)
#   adding: generated_images/image_00429.png (stored 0%)
#   adding: generated_images/image_00214.png (stored 0%)
#   adding: generated_images/image_00475.png (stored 0%)
#   adding: generated_images/image_00478.png (stored 0%)
#   adding: generated_images/image_00707.png (stored 0%)
#   adding: generated_images/image_00891.png (stored 0%)
#   adding: generated_images/image_00950.png (stored 0%)
#   adding: generated_images/image_00941.png (stored 0%)
#   adding: generated_images/image_00198.png (deflated 2%)
#   adding: generated_images/image_00256.png (stored 0%)
#   adding: generated_images/image_00734.png (stored 0%)
#   adding: generated_images/image_00348.png (stored 0%)
#   adding: generated_images/image_00473.png (stored 0%)
#   adding: generated_images/image_00586.png (stored 0%)
#   adding: generated_images/image_00084.png (stored 0%)
#   adding: generated_images/image_00038.png (stored 0%)
#   adding: generated_images/image_00143.png (stored 0%)
#   adding: generated_images/image_00319.png (stored 0%)
#   adding: generated_images/image_00814.png (stored 0%)
#   adding: generated_images/image_00488.png (deflated 0%)
#   adding: generated_images/image_00602.png (stored 0%)
#   adding: generated_images/image_00683.png (stored 0%)
#   adding: generated_images/image_00511.png (stored 0%)
#   adding: generated_images/image_00494.png (stored 0%)
#   adding: generated_images/image_00107.png (stored 0%)
#   adding: generated_images/image_00078.png (deflated 0%)
#   adding: generated_images/image_00557.png (stored 0%)
#   adding: generated_images/image_00900.png (stored 0%)
#   adding: generated_images/image_00935.png (stored 0%)
#   adding: generated_images/image_00677.png (stored 0%)
#   adding: generated_images/image_00629.png (deflated 1%)
#   adding: generated_images/image_00823.png (stored 0%)
#   adding: generated_images/image_00103.png (stored 0%)
#   adding: generated_images/image_00519.png (stored 0%)
#   adding: generated_images/image_00260.png (stored 0%)
#   adding: generated_images/image_00155.png (deflated 1%)
#   adding: generated_images/image_00853.png (stored 0%)
#   adding: generated_images/image_00500.png (stored 0%)
#   adding: generated_images/image_00625.png (stored 0%)
#   adding: generated_images/image_00861.png (stored 0%)
#   adding: generated_images/image_00896.png (stored 0%)
#   adding: generated_images/image_00924.png (stored 0%)
#   adding: generated_images/image_00845.png (stored 0%)
#   adding: generated_images/image_00627.png (stored 0%)
#   adding: generated_images/image_00074.png (stored 0%)
#   adding: generated_images/image_00229.png (stored 0%)
#   adding: generated_images/image_00527.png (deflated 2%)
#   adding: generated_images/image_00529.png (stored 0%)
#   adding: generated_images/image_00346.png (stored 0%)
#   adding: generated_images/image_00397.png (stored 0%)
#   adding: generated_images/image_00549.png (stored 0%)
#   adding: generated_images/image_00784.png (stored 0%)
#   adding: generated_images/image_00040.png (stored 0%)
#   adding: generated_images/image_00757.png (stored 0%)
#   adding: generated_images/image_00870.png (stored 0%)
#   adding: generated_images/image_00522.png (stored 0%)
#   adding: generated_images/image_00327.png (stored 0%)
#   adding: generated_images/image_00835.png (stored 0%)
#   adding: generated_images/image_00436.png (stored 0%)
#   adding: generated_images/image_00708.png (stored 0%)
#   adding: generated_images/image_00146.png (stored 0%)
#   adding: generated_images/image_00573.png (stored 0%)
#   adding: generated_images/image_00069.png (stored 0%)
#   adding: generated_images/image_00259.png (stored 0%)
#   adding: generated_images/image_00177.png (stored 0%)
#   adding: generated_images/image_00075.png (stored 0%)
#   adding: generated_images/image_00304.png (stored 0%)
#   adding: generated_images/image_00072.png (stored 0%)
#   adding: generated_images/image_00964.png (stored 0%)
